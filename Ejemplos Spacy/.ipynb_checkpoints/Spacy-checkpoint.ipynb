# %%
import spacy

# %%
nlp = spacy.load("es_core_news_sm")

# %%
doc = nlp("Esto es una frase de pruebas, para analizar el documento.")

# %%
for palabra in doc:
    print (palabra, palabra.pos_, palabra.dep_)
# Out:
# Esto PRON nsubj
# es AUX cop
# una DET det
# frase NOUN ROOT
# de ADP case
# pruebas NOUN nmod
# , PUNCT punct
# para ADP mark
# analizar VERB acl
# el DET det
# documento NOUN obj
# . PUNCT punct

# %%
for token in doc:
    print (token.text)
# Out:
# Esto
# es
# una
# frase
# de
# pruebas
# ,
# para
# analizar
# el
# documento
# .

# %%
doc2 = nlp("Esta es la primera frase. Esta es la segunda frase. Esta es la tercera frase")

# %%
for frase in doc2.sents:
    print(frase)
# Out:
# Esta es la primera frase.
# Esta es la segunda frase.
# Esta es la tercera frase

# %%
doc3 = nlp("Los carros electricos seran decisivos para afrontar las nuevas megatendencias de la sociedad del futuro.")

# %%
for partes in doc3.noun_chunks:
    print(partes)
# Out:
# Los carros electricos
# las nuevas megatendencias
# la sociedad
# futuro

# %%
from spacy import displacy

# %%
doc4 = nlp("Google ha comprado una empresa por 5 millones de dolares")

# %%
displacy.render(doc4, style="dep", options={"distance":100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="f01c2fa654e44e55ba0dca7e9df184d7-0" class="displacy" width="1050" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">ha</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">comprado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">una</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">empresa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">millones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">dolares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-0" stroke-width="2px" d="M70,152.0 C70,52.0 245.0,52.0 245.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-2" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,154.0 L362,142.0 378,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-3" stroke-width="2px" d="M270,152.0 C270,52.0 445.0,52.0 445.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,154.0 L453.0,142.0 437.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-4" stroke-width="2px" d="M570,152.0 C570,52.0 745.0,52.0 745.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,154.0 L562,142.0 578,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-5" stroke-width="2px" d="M670,152.0 C670,102.0 740.0,102.0 740.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,154.0 L662,142.0 678,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-6" stroke-width="2px" d="M270,152.0 C270,2.0 750.0,2.0 750.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,154.0 L758.0,142.0 742.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-7" stroke-width="2px" d="M870,152.0 C870,102.0 940.0,102.0 940.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,154.0 L862,142.0 878,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-8" stroke-width="2px" d="M770,152.0 C770,52.0 945.0,52.0 945.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f01c2fa654e44e55ba0dca7e9df184d7-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945.0,154.0 L953.0,142.0 937.0,142.0" fill="currentColor"/>
# <

# %%
displacy.render(doc4, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ha comprado una empresa por 5 millones de dolares</div></span>

# %%
texto = """
Muy buenas tardes.
Señor alcalde de Quito, Pabel Muñoz, un gusto tenerlo aquí
de nuevo. A todos nuestros ministros que están peleando día
a día para sacar adelante el país, un gran saludo a todo su
equipo de trabajo y a todo el equipo del Municipio de Quito.
Algunas caras conocidas aquí, a algunos los conocí en la
Asamblea. Siempre tuve una gran admiración por su equipo
de trabajo, por la gente que conocí durante ese tiempo.
Uno tiene que ser agradecido en la vida. Gracias a Quito es
que estoy parado aquí. Gracias a Quito soy Presidente de la
República.
El apoyo que la ciudad de Quito me dio en cada uno de sus
rincones fue determinante. Inclusive, también en los días
bajos, cuando hacíamos campaña en Quito, siempre era una
manera de levantarnos el ánimo y el pensar que sí era
posible hacer las cosas diferentes y que sí era posible que un
joven candidato pueda ser presidente de la república.
Para mí, Quito estará siempre en mi corazón, y siempre
tendrá mi respeto y apoyo. Si Quito está bien, el resto del
país progresará. Si Quito logra tener la paz, podremos
también replicarlo en el resto de la nación.
Entonces, una vez más agradecerles por su atención.
Agradecerles por este detalle. Nunca me olvidaré. Y ahora,
pues, a celebrar juntos, a bailar juntos, a cantar juntos.
Es un momento de alegría. Son las fiestas de Quito y
debemos de disfrutarla, y debemos de celebrarla como la
ciudad se merece.
Muchas gracias.
"""

# %%
doc = nlp(texto)

# %%
print("Token\t\tPOS")
for token in doc:
    print(f"{token.text}\t\t{token.pos_}")
# Out:
# Token		POS
#
# 		SPACE
# Muy		ADV
# buenas		ADJ
# tardes		NOUN
# .		PUNCT
#
# 		SPACE
# Señor		NOUN
# alcalde		NOUN
# de		ADP
# Quito		PROPN
# ,		PUNCT
# Pabel		PROPN
# Muñoz		PROPN
# ,		PUNCT
# un		DET
# gusto		NOUN
# tenerlo		VERB
# aquí		ADV
#
# 		SPACE
# de		ADP
# nuevo		ADJ
# .		PUNCT
# A		ADP
# todos		DET
# nuestros		DET
# ministros		NOUN
# que		PRON
# están		AUX
# peleando		VERB
# día		NOUN
#
# 		SPACE
# a		ADP
# día		NOUN
# para		ADP
# sacar		VERB
# adelante		NOUN
# el		DET
# país		NOUN
# ,		PUNCT
# un		DET
# gran		ADJ
# saludo		NOUN
# a		ADP
# todo		DET
# su		DET
#
# 		SPACE
# equipo		NOUN
# de		ADP
# trabajo		NOUN
# y		CCONJ
# a		ADP
# todo		DET
# el		DET
# equipo		NOUN
# del		ADP
# Municipio		PROPN
# de		ADP
# Quito		PROPN
# .		PUNCT
#
# 		SPACE
# Algunas		DET
# caras		NOUN
# conocidas		ADJ
# aquí		ADV
# ,		PUNCT
# a		ADP
# algunos		PRON
# los		DET
# conocí		VERB
# en		ADP
# la		DET
#
# 		SPACE
# Asamblea		PROPN
# .		PUNCT
# Siempre		ADV
# tuve		VERB
# una		DET
# gran		ADJ
# admiración		NOUN
# por		ADP
# su		DET
# equipo		NOUN
#
# 		SPACE
# de		ADP
# trabajo		NOUN
# ,		PUNCT
# por		ADP
# la		DET
# gente		NOUN
# que		PRON
# conocí		VERB
# durante		ADP
# ese		DET
# tiempo		NOUN
# .		PUNCT
#
# 		SPACE
# Uno		PRON
# tiene		VERB
# que		SCONJ
# ser		AUX
# agradecido		VERB
# en		ADP
# la		DET
# vida		NOUN
# .		PUNCT
# Gracias		NOUN
# a		ADP
# Quito		PROPN
# es		AUX
#
# 		SPACE
# que		SCONJ
# estoy		AUX
# parado		ADJ
# aquí		ADV
# .		PUNCT
# Gracias		NOUN
# a		ADP
# Quito		PROPN
# soy		AUX
# Presidente		PROPN
# de		ADP
# la		DET
#
# 		SPACE
# República		PROPN
# .		PUNCT
#
# 		SPACE
# El		DET
# apoyo		NOUN
# que		PRON
# la		DET
# ciudad		NOUN
# de		ADP
# Quito		PROPN
# me		PRON
# dio		VERB
# en		ADP
# cada		DET
# uno		PRON
# de		ADP
# sus		DET
#
# 		SPACE
# rincones		NOUN
# fue		AUX
# determinante		ADJ
# .		PUNCT
# Inclusive		PROPN
# ,		PUNCT
# también		ADV
# en		ADP
# los		DET
# días		NOUN
#
# 		SPACE
# bajos		ADJ
# ,		PUNCT
# cuando		SCONJ
# hacíamos		VERB
# campaña		NOUN
# en		ADP
# Quito		PROPN
# ,		PUNCT
# siempre		ADV
# era		AUX
# una		DET
#
# 		SPACE
# manera		NOUN
# de		ADP
# levantarnos		NOUN
# el		DET
# ánimo		NOUN
# y		CCONJ
# el		DET
# pensar		VERB
# que		SCONJ
# sí		INTJ
# era		AUX
#
# 		SPACE
# posible		ADJ
# hacer		VERB
# las		DET
# cosas		NOUN
# diferentes		ADJ
# y		CCONJ
# que		PRON
# sí		INTJ
# era		AUX
# posible		ADJ
# que		SCONJ
# un		DET
#
# 		SPACE
# joven		ADJ
# candidato		NOUN
# pueda		AUX
# ser		AUX
# presidente		NOUN
# de		ADP
# la		DET
# república		NOUN
# .		PUNCT
#
# 		SPACE
# Para		ADP
# mí		PRON
# ,		PUNCT
# Quito		PROPN
# estará		AUX
# siempre		ADV
# en		ADP
# mi		DET
# corazón		NOUN
# ,		PUNCT
# y		CCONJ
# siempre		ADV
#
# 		SPACE
# tendrá		VERB
# mi		DET
# respeto		NOUN
# y		CCONJ
# apoyo		NOUN
# .		PUNCT
# Si		SCONJ
# Quito		PROPN
# está		AUX
# bien		ADV
# ,		PUNCT
# el		DET
# resto		NOUN
# del		ADP
#
# 		SPACE
# país		NOUN
# progresará		VERB
# .		PUNCT
# Si		SCONJ
# Quito		PROPN
# logra		VERB
# tener		VERB
# la		DET
# paz		NOUN
# ,		PUNCT
# podremos		AUX
#
# 		SPACE
# también		ADV
# replicarlo		VERB
# en		ADP
# el		DET
# resto		NOUN
# de		ADP
# la		DET
# nación		NOUN
# .		PUNCT
#
# 		SPACE
# Entonces		ADV
# ,		PUNCT
# una		DET
# vez		NOUN
# más		ADV
# agradecerles		ADJ
# por		ADP
# su		DET
# atención		NOUN
# .		PUNCT
#
# 		SPACE
# Agradecerles		PROPN
# por		ADP
# este		DET
# detalle		NOUN
# .		PUNCT
# Nunca		ADV
# me		PRON
# olvidaré		VERB
# .		PUNCT
# Y		CCONJ
# ahora		ADV
# ,		PUNCT
#
# 		SPACE
# pues		SCONJ
# ,		PUNCT
# a		ADP
# celebrar		VERB
# juntos		ADJ
# ,		PUNCT
# a		ADP
# bailar		VERB
# juntos		ADJ
# ,		PUNCT
# a		ADP
# cantar		VERB
# juntos		ADJ
# .		PUNCT
#
# 		SPACE
# Es		AUX
# un		DET
# momento		NOUN
# de		ADP
# alegría		NOUN
# .		PUNCT
# Son		AUX
# las		DET
# fiestas		NOUN
# de		ADP
# Quito		PROPN
# y		CCONJ
#
# 		SPACE
# debemos		AUX
# de		ADP
# disfrutarla		VERB
# ,		PUNCT
# y		CCONJ
# debemos		AUX
# de		ADP
# celebrarla		VERB
# como		SCONJ
# la		DET
#
# 		SPACE
# ciudad		NOUN
# se		PRON
# merece		VERB
# .		PUNCT
#
# 		SPACE
# Muchas		PRON
# gracias		NOUN
# .		PUNCT
#
# 		SPACE

# %%
print("\nEntidades Nombradas:")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Entidades Nombradas:
# Señor LOC
# Quito LOC
# Pabel Muñoz PER
# Municipio de Quito LOC
# Asamblea ORG
# Uno LOC
# Gracias LOC
# Quito LOC
# Gracias LOC
# Quito LOC
# Presidente de la
# República MISC
# Quito LOC
# Inclusive MISC
# días
# bajos LOC
# Quito LOC
# Para mí MISC
# Quito LOC
# corazón LOC
# Si Quito PER
# Si Quito ORG
# Agradecerles LOC
# Quito LOC

# %%
print("\nDependencias Sintácticas:")
for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# Dependencias Sintácticas:
#
#  dep
#
# Muy advmod tardes
# buenas amod tardes
# tardes ROOT tardes
# . punct tardes
#
#  dep .
# Señor ROOT Señor
# alcalde appos Señor
# de case Quito
# Quito nmod alcalde
# , punct Pabel
# Pabel appos alcalde
# Muñoz flat Pabel
# , punct gusto
# un det gusto
# gusto appos Señor
# tenerlo acl gusto
# aquí advmod tenerlo
#
#  dep aquí
# de advmod tenerlo
# nuevo fixed de
# . punct Señor
# A case ministros
# todos det nuestros
# nuestros det ministros
# ministros ROOT ministros
# que nsubj peleando
# están aux peleando
# peleando acl ministros
# día obj peleando
#
#  dep día
# a case día
# día nmod día
# para mark sacar
# sacar advcl peleando
# adelante advmod sacar
# el det país
# país obj sacar
# , punct saludo
# un det saludo
# gran amod saludo
# saludo appos país
# a case equipo
# todo det su
# su det equipo
#
#  dep su
# equipo nmod saludo
# de case trabajo
# trabajo nmod equipo
# y cc equipo
# a case equipo
# todo det el
# el det equipo
# equipo conj equipo
# del case Municipio
# Municipio nmod equipo
# de case Quito
# Quito flat Municipio
# . punct ministros
#
#  dep .
# Algunas det caras
# caras ROOT caras
# conocidas amod caras
# aquí advmod conocidas
# , punct conocí
# a case conocí
# algunos det los
# los det conocí
# conocí appos caras
# en case Asamblea
# la det Asamblea
#
#  dep la
# Asamblea obl conocí
# . punct caras
# Siempre advmod tuve
# tuve ROOT tuve
# una det admiración
# gran amod admiración
# admiración obj tuve
# por case equipo
# su det equipo
# equipo nmod admiración
#
#  dep equipo
# de case trabajo
# trabajo nmod equipo
# , punct gente
# por case gente
# la det gente
# gente obl tuve
# que obj conocí
# conocí acl gente
# durante case tiempo
# ese det tiempo
# tiempo obl conocí
# . punct tuve
#
#  dep .
# Uno nsubj agradecido
# tiene ROOT tiene
# que cc agradecido
# ser cop agradecido
# agradecido conj tiene
# en case vida
# la det vida
# vida obl agradecido
# . punct tiene
# Gracias case Quito
# a fixed Gracias
# Quito obl parado
# es cop parado
#
#  dep es
# que mark parado
# estoy cop parado
# parado ROOT parado
# aquí advmod parado
# . punct parado
# Gracias case Quito
# a fixed Gracias
# Quito obl Presidente
# soy cop Presidente
# Presidente ROOT Presidente
# de case República
# la det República
#
#  dep la
# República flat Presidente
# . punct Presidente
#
#  dep .
# El det apoyo
# apoyo nsubj determinante
# que obj dio
# la det ciudad
# ciudad nsubj dio
# de case Quito
# Quito nmod ciudad
# me iobj dio
# dio acl apoyo
# en case uno
# cada det uno
# uno obl dio
# de case rincones
# sus det rincones
#
#  dep sus
# rincones nmod uno
# fue cop determinante
# determinante ROOT determinante
# . punct determinante
# Inclusive nsubj manera
# , punct también
# también advmod Inclusive
# en case también
# los det días
# días nmod también
#
#  dep días
# bajos amod días
# , punct hacíamos
# cuando mark hacíamos
# hacíamos advcl Inclusive
# campaña obj hacíamos
# en case Quito
# Quito obl hacíamos
# , punct hacíamos
# siempre advmod manera
# era cop manera
# una det manera
#
#  dep una
# manera ROOT manera
# de mark levantarnos
# levantarnos acl manera
# el det ánimo
# ánimo obj levantarnos
# y cc pensar
# el det pensar
# pensar conj manera
# que nsubj posible
# sí advcl posible
# era cop posible
#
#  dep era
# posible ccomp pensar
# hacer csubj posible
# las det cosas
# cosas obj hacer
# diferentes amod cosas
# y cc posible
# que nsubj posible
# sí advcl posible
# era cop posible
# posible conj posible
# que mark presidente
# un det joven
#
#  dep un
# joven amod candidato
# candidato nsubj presidente
# pueda aux presidente
# ser cop presidente
# presidente csubj posible
# de case república
# la det república
# república nmod presidente
# . punct manera
#
#  dep .
# Para case mí
# mí obl siempre
# , punct mí
# Quito nsubj siempre
# estará cop siempre
# siempre ROOT siempre
# en case corazón
# mi det corazón
# corazón nmod siempre
# , punct tendrá
# y cc tendrá
# siempre advmod tendrá
#
#  dep siempre
# tendrá conj siempre
# mi det respeto
# respeto obj tendrá
# y cc apoyo
# apoyo conj respeto
# . punct siempre
# Si mark bien
# Quito nsubj bien
# está cop bien
# bien advcl progresará
# , punct resto
# el det resto
# resto nsubj progresará
# del case país
#
#  dep del
# país nmod resto
# progresará ROOT progresará
# . punct progresará
# Si mark logra
# Quito nsubj logra
# logra advcl replicarlo
# tener xcomp logra
# la det paz
# paz obj tener
# , punct logra
# podremos aux replicarlo
#
#  dep podremos
# también advmod podremos
# replicarlo ROOT replicarlo
# en case resto
# el det resto
# resto obl replicarlo
# de case resto
# la det nación
# nación nmod resto
# . punct replicarlo
#
#  dep .
# Entonces advmod agradecerles
# , punct agradecerles
# una det vez
# vez obj agradecerles
# más advmod agradecerles
# agradecerles ROOT agradecerles
# por case atención
# su det atención
# atención obl agradecerles
# . punct agradecerles
#
#  dep .
# Agradecerles ROOT Agradecerles
# por case detalle
# este det detalle
# detalle nmod Agradecerles
# . punct Agradecerles
# Nunca advmod olvidaré
# me expl:pv olvidaré
# olvidaré ROOT olvidaré
# . punct olvidaré
# Y ROOT Y
# ahora dep Y
# , punct celebrar
#
#  dep ,
# pues mark ,
# , punct celebrar
# a mark celebrar
# celebrar advcl ahora
# juntos obj celebrar
# , punct celebrar
# a mark bailar
# bailar advcl celebrar
# juntos obj bailar
# , punct bailar
# a mark cantar
# cantar xcomp celebrar
# juntos obj cantar
# . punct celebrar
#
#  dep .
# Es cop momento
# un det momento
# momento ROOT momento
# de case alegría
# alegría nmod momento
# . punct momento
# Son cop fiestas
# las det fiestas
# fiestas ROOT fiestas
# de case Quito
# Quito nmod fiestas
# y cc disfrutarla
#
#  dep y
# debemos aux disfrutarla
# de mark disfrutarla
# disfrutarla conj fiestas
# , punct celebrarla
# y cc celebrarla
# debemos aux celebrarla
# de mark celebrarla
# celebrarla advcl merece
# como mark ciudad
# la det ciudad
#
#  dep la
# ciudad obl celebrarla
# se expl:pv merece
# merece conj fiestas
# . punct fiestas
#
#  dep .
# Muchas ROOT Muchas
# gracias flat Muchas
# . punct Muchas
#
#  dep .

# %%
print("\nLematización:")
for token in doc:
    print(token.text, token.lemma_)
# Out:
# Lematización:
#
#
#
# Muy mucho
# buenas buena
# tardes tarde
# . .
#
#
#
# Señor señor
# alcalde alcalde
# de de
# Quito Quito
# , ,
# Pabel Pabel
# Muñoz Muñoz
# , ,
# un uno
# gusto gusto
# tenerlo tener él
# aquí aquí
#
#
#
# de de
# nuevo nuevo
# . .
# A a
# todos todo
# nuestros nuestro
# ministros ministro
# que que
# están estar
# peleando pelear
# día día
#
#
#
# a a
# día día
# para para
# sacar sacar
# adelante adelante
# el el
# país país
# , ,
# un uno
# gran gran
# saludo saludo
# a a
# todo todo
# su su
#
#
#
# equipo equipo
# de de
# trabajo trabajo
# y y
# a a
# todo todo
# el el
# equipo equipo
# del del
# Municipio Municipio
# de de
# Quito Quito
# . .
#
#
#
# Algunas alguno
# caras cara
# conocidas conocido
# aquí aquí
# , ,
# a a
# algunos alguno
# los el
# conocí conocer
# en en
# la el
#
#
#
# Asamblea Asamblea
# . .
# Siempre siempre
# tuve tener
# una uno
# gran gran
# admiración admiración
# por por
# su su
# equipo equipo
#
#
#
# de de
# trabajo trabajo
# , ,
# por por
# la el
# gente gente
# que que
# conocí conocer
# durante durante
# ese ese
# tiempo tiempo
# . .
#
#
#
# Uno uno
# tiene tener
# que que
# ser ser
# agradecido agradecer
# en en
# la el
# vida vida
# . .
# Gracias gracias
# a a
# Quito Quito
# es ser
#
#
#
# que que
# estoy estar
# parado parado
# aquí aquí
# . .
# Gracias gracias
# a a
# Quito Quito
# soy ser
# Presidente Presidente
# de de
# la el
#
#
#
# República República
# . .
#
#
#
# El el
# apoyo apoyo
# que que
# la el
# ciudad ciudad
# de de
# Quito Quito
# me yo
# dio dar
# en en
# cada cada
# uno uno
# de de
# sus su
#
#
#
# rincones rincón
# fue ser
# determinante determinante
# . .
# Inclusive Inclusive
# , ,
# también también
# en en
# los el
# días día
#
#
#
# bajos bajo
# , ,
# cuando cuando
# hacíamos hacíar
# campaña campaña
# en en
# Quito Quito
# , ,
# siempre siempre
# era ser
# una uno
#
#
#
# manera manera
# de de
# levantarnos levantarno
# el el
# ánimo ánimo
# y y
# el el
# pensar pensar
# que que
# sí sí
# era ser
#
#
#
# posible posible
# hacer hacer
# las el
# cosas cosa
# diferentes diferente
# y y
# que que
# sí sí
# era ser
# posible posible
# que que
# un uno
#
#
#
# joven joven
# candidato candidato
# pueda poder
# ser ser
# presidente presidente
# de de
# la el
# república república
# . .
#
#
#
# Para para
# mí yo
# , ,
# Quito Quito
# estará estar
# siempre siempre
# en en
# mi mi
# corazón corazón
# , ,
# y y
# siempre siempre
#
#
#
# tendrá tener
# mi mi
# respeto respeto
# y y
# apoyo apoyo
# . .
# Si si
# Quito Quito
# está estar
# bien bien
# , ,
# el el
# resto resto
# del del
#
#
#
# país país
# progresará progresar
# . .
# Si si
# Quito Quito
# logra lograr
# tener tener
# la el
# paz paz
# , ,
# podremos poder
#
#
#
# también también
# replicarlo replicar él
# en en
# el el
# resto resto
# de de
# la el
# nación nación
# . .
#
#
#
# Entonces entonces
# , ,
# una uno
# vez vez
# más más
# agradecerles agradecerl
# por por
# su su
# atención atención
# . .
#
#
#
# Agradecerles Agradecerles
# por por
# este este
# detalle detalle
# . .
# Nunca nunca
# me yo
# olvidaré olvidar
# . .
# Y y
# ahora ahora
# , ,
#
#
#
# pues pues
# , ,
# a a
# celebrar celebrar
# juntos junto
# , ,
# a a
# bailar bailar
# juntos junto
# , ,
# a a
# cantar cantar
# juntos junto
# . .
#
#
#
# Es ser
# un uno
# momento momento
# de de
# alegría alegría
# . .
# Son ser
# las el
# fiestas fiesta
# de de
# Quito Quito
# y y
#
#
#
# debemos deber
# de de
# disfrutarla disfrutar él
# , ,
# y y
# debemos deber
# de de
# celebrarla celebrar él
# como como
# la el
#
#
#
# ciudad ciudad
# se él
# merece merecer
# . .
#
#
#
# Muchas mucho
# gracias gracia
# . .

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="fd8d1717869c4208a158f1b26c8687e2-0" class="displacy" width="49575" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Muy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">buenas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">tardes.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Señor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">alcalde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Quito,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Pabel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Muñoz,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">gusto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">tenerlo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">aquí</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">nuevo.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">todos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">nuestros</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">ministros</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">están</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">peleando</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">día</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">día</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">para</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">sacar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">VER

# %%
print("\nOraciones más importantes:")
for sent in doc.sents:
    if "Q" in sent.text:
        print(sent.text.strip())
# Out:
# Oraciones más importantes:
# Señor alcalde de Quito, Pabel Muñoz, un gusto tenerlo aquí
# de nuevo.
# A todos nuestros ministros que están peleando día
# a día para sacar adelante el país, un gran saludo a todo su
# equipo de trabajo y a todo el equipo del Municipio de Quito.
# Gracias a Quito es
# que estoy parado aquí.
# Gracias a Quito soy Presidente de la
# República.
# El apoyo que la ciudad de Quito me dio en cada uno de sus
# rincones fue determinante.
# Inclusive, también en los días
# bajos, cuando hacíamos campaña en Quito, siempre era una
# manera de levantarnos el ánimo y el pensar que sí era
# posible hacer las cosas diferentes y que sí era posible que un
# joven candidato pueda ser presidente de la república.
# Para mí, Quito estará siempre en mi corazón, y siempre
# tendrá mi respeto y apoyo.
# Si Quito está bien, el resto del
# país progresará.
# Si Quito logra tener la paz, podremos
# también replicarlo en el resto de la nación.
# Son las fiestas de Quito y
# debemos de disfrutarla, y debemos de celebrarla como la
# ciudad se merece.
